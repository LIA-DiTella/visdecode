# %%
import torch
from datasets import load_dataset
import matplotlib.pyplot as plt
import numpy as np
from huggingface_hub import login

# %%
#login(token = "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")

#ploty_dataset_train = load_dataset("martinsinnona/ploty", split = "train")
#ploty_dataset_test = load_dataset("martinsinnona/ploty", split = "test")

ploty_dataset_train = load_dataset("imagefolder", data_dir = "dataset", split = "train")
ploty_dataset_test = load_dataset("imagefolder", data_dir = "dataset", split = "test")
# Out:
# Resolving data files:   0%|          | 0/101 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/60 [00:00<?, ?it/s]
# Downloading and preparing dataset imagefolder/default to C:/Users/marti/.cache/huggingface/datasets/imagefolder/default-86878d9d2f705fd5/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f...
# Downloading data files:   0%|          | 0/103 [00:00<?, ?it/s]
# Downloading data files: 0it [00:00, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Downloading data files:   0%|          | 0/62 [00:00<?, ?it/s]
# Downloading data files: 0it [00:00, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset imagefolder downloaded and prepared to C:/Users/marti/.cache/huggingface/datasets/imagefolder/default-86878d9d2f705fd5/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f. Subsequent calls will reuse this data.
# Resolving data files:   0%|          | 0/101 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/60 [00:00<?, ?it/s]
# Found cached dataset imagefolder (C:/Users/marti/.cache/huggingface/datasets/imagefolder/default-86878d9d2f705fd5/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f)

# %%
print(ploty_dataset_train, ploty_dataset_test)
# Out:
# Dataset({
#     features: ['image', 'text'],
#     num_rows: 100
# }) Dataset({
#     features: ['image', 'text'],
#     num_rows: 59
# })

# %%
from torch.utils.data import Dataset, DataLoader

MAX_PATCHES = 1024

class ImageCaptioningDataset(Dataset):

    def __init__(self, dataset, processor):
        self.dataset = dataset
        self.processor = processor

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):

        item = self.dataset[idx]
        encoding = self.processor(images=item["image"], text = "", return_tensors="pt", add_special_tokens=True, max_patches=MAX_PATCHES)

        encoding = {k:v.squeeze() for k,v in encoding.items()}
        encoding["text"] = item["text"]

        return encoding

# %%
from transformers import AutoProcessor, Pix2StructForConditionalGeneration

processor = AutoProcessor.from_pretrained("ybelkada/pix2struct-base")
model = Pix2StructForConditionalGeneration.from_pretrained("google/matcha-base")

# %%
def collator(batch):

  new_batch = {"flattened_patches":[], "attention_mask":[]}
  texts = [item["text"] for item in batch]

  text_inputs = processor(text=texts, padding="max_length", return_tensors="pt", add_special_tokens=True, max_length=200)

  new_batch["labels"] = text_inputs.input_ids

  for item in batch:
    new_batch["flattened_patches"].append(item["flattened_patches"])
    new_batch["attention_mask"].append(item["attention_mask"])

  new_batch["flattened_patches"] = torch.stack(new_batch["flattened_patches"])
  new_batch["attention_mask"] = torch.stack(new_batch["attention_mask"])

  return new_batch

# %%
train_dataset = ImageCaptioningDataset(ploty_dataset_train, processor)
train_dataloader = DataLoader(train_dataset, shuffle=True, batch_size=2, collate_fn=collator)

# %%
def eval_model(dataset):
    
    results = []
    i = 0
    
    for data in dataset:
        
        if i % 10 == 0: print(i)
        i += 1
        
        image = data["image"]

        model.eval()
        inputs = processor(images=image, return_tensors="pt", max_patches=512).to(device)

        flattened_patches = inputs.flattened_patches
        attention_mask = inputs.attention_mask

        generated_ids = model.generate(flattened_patches=flattened_patches, attention_mask=attention_mask, max_length=200)
        generated_caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

        results.append([data["text"], generated_caption])

    return np.mean([res[0] == res[1] for res in results])

# %%
seed = 14895215085708117999
torch.manual_seed(seed)

# %%
EPOCHS = 100
eval_step = 50

optimizer = torch.optim.AdamW(model.parameters(), lr = 1e-5)

device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
model.train()

losses = []
accuracies_train = []
accuracies_test = []

for epoch in range(EPOCHS + 1):

    print("Epoch:", epoch)
    for idx, batch in enumerate(train_dataloader):

        labels = batch.pop("labels").to(device)
        flattened_patches = batch.pop("flattened_patches").to(device)
        attention_mask = batch.pop("attention_mask").to(device)

        outputs = model(flattened_patches = flattened_patches,
                    attention_mask = attention_mask,
                    labels = labels)

        loss = outputs.loss
        print("Loss:", loss.item())

        loss.backward()

        optimizer.step()
        optimizer.zero_grad()

        if (epoch + 1) % 50 == 0:

            model.eval()

            predictions = model.generate(flattened_patches = flattened_patches, attention_mask = attention_mask)
            print("Predictions:", processor.batch_decode(predictions, skip_special_tokens = True))

            model.train()
        
    if epoch % eval_step == 0:

        #accuracy_train = eval_model(ploty_dataset_train)
        accuracy_train = 0
        accuracy_test = eval_model(ploty_dataset_test)

        accuracies_train.append(accuracy_train)
        accuracies_test.append(accuracy_test)
        
        print("\n\nAccuracy (train): " + str(accuracy_train) + "\n")
        print("Accuracy (test): " + str(accuracy_test) + "\n")
        print(accuracies_train)
        print(accuracies_test)
        print("\n")

    losses.append(loss.cpu().detach().numpy().item())
# Out:
# Epoch: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\marti\Desktop\ditella-repo\visdecode\matcha.ipynb Cell 10 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/marti/Desktop/ditella-repo/visdecode/matcha.ipynb#X20sZmlsZQ%3D%3D?line=19'>20</a> flattened_patches = batch.pop("flattened_patches").to(device)
#      <a href='vscode-notebook-cell:/c%3A/Users/marti/Desktop/ditella-repo/visdecode/matcha.ipynb#X20sZmlsZQ%3D%3D?line=20'>21</a> attention_mask = batch.pop("attention_mask").to(device)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/marti/Desktop/ditella-repo/visdecode/matcha.ipynb#X20sZmlsZQ%3D%3D?line=22'>23</a> outputs = model(flattened_patches = flattened_patches,
#      <a href='vscode-notebook-cell:/c%3A/Users/marti/Desktop/ditella-repo/visdecode/matcha.ipynb#X20sZmlsZQ%3D%3D?line=23'>24</a>             attention_mask = attention_mask,
#      <a href='vscode-notebook-cell:/c%3A/Users/marti/Desktop/ditella-repo/visdecode/matcha.ipynb#X20sZmlsZQ%3D%3D?line=24'>25</a>             labels = labels)
#      <a href='vscode-notebook-cell:/c%3A/Users/marti/Desktop/ditella-repo/visdecode/matcha.ipynb#X20sZmlsZQ%3D%3D?line=26'>27</a> loss = outputs.loss
#      <a href='vscode-notebook-cell:/c%3A/Users/marti/Desktop/ditella-repo/visdecode/matcha.ipynb#X20sZmlsZQ%3D%3D?line=27'>28</a> print("Loss:", loss.item())
#
# File c:\Users\marti\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\marti\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\pix2struct\modeling_pix2struct.py:1729, in Pix2StructForConditionalGeneration.forward(self, flattened_patches, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, labels, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1727 # Encode if needed (training, first prediction pass)
#    1728 if encoder_outputs is None:
# -> 1729     encoder_outputs = self.encoder(
#    1730         flattened_patches=flattened_patches,
#    1731         attention_mask=attention_mask,
#    1732         head_mask=head_mask,
#    1733         output_attentions=output_attentions,
#    1734         output_hidden_states=output_hidden_states,
#    1735         return_dict=return_dict,
#    1736     )
#    1737 elif return_dict and not isinstance(encoder_outputs, BaseModelOutput):
#    1738     encoder_outputs = BaseModelOutput(
#    1739         last_hidden_state=encoder_outputs[0],
#    1740         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1741         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1742     )
#
# File c:\Users\marti\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\marti\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\pix2struct\modeling_pix2struct.py:639, in Pix2StructVisionModel.forward(self, flattened_patches, attention_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     635 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     637 embedding_output = self.embeddings(flattened_patches)
# --> 639 encoder_outputs = self.encoder(
#     640     embedding_output,
#     641     attention_mask=attention_mask,
#     642     head_mask=head_mask,
#     643     output_attentions=output_attentions,
#     644     output_hidden_states=output_hidden_states,
#     645     return_dict=return_dict,
#     646 )
#     647 sequence_output = encoder_outputs[0]
#     648 sequence_output = self.layernorm(sequence_output)
#
# File c:\Users\marti\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\marti\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\pix2struct\modeling_pix2struct.py:360, in Pix2StructVisionEncoder.forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     353     layer_outputs = torch.utils.checkpoint.checkpoint(
#     354         create_custom_forward(layer_module),
#     355         hidden_states,
#     356         attention_mask,
#     357         layer_head_mask,
#     358     )
#     359 else:
# --> 360     layer_outputs = layer_module(hidden_states, attention_mask, layer_head_mask, output_attentions)
#     362 hidden_states = layer_outputs[0]
#     364 if output_attentions:
#
# File c:\Users\marti\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\marti\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\pix2struct\modeling_pix2struct.py:299, in Pix2StructVisionLayer.forward(self, hidden_states, attention_mask, head_mask, output_attentions)
#     296 # in Pix2StructVision, layernorm is applied before self-attention
#     297 hidden_states = self.pre_attention_layer_norm(hidden_states)
# --> 299 self_attention_outputs = self.attention(
#     300     hidden_states,
#     301     attention_mask=attention_mask,
#     302     layer_head_mask=head_mask,
#     303     output_attentions=output_attentions,
#     304 )
#     305 attention_output = self_attention_outputs[0]
#     306 outputs = self_attention_outputs[1:]  # add self attentions if we output attention weights
#
# File c:\Users\marti\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\marti\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\pix2struct\modeling_pix2struct.py:221, in Pix2StructVisionAttention.forward(self, hidden_states, attention_mask, position_bias, layer_head_mask, output_attentions)
#     219 position_bias_masked = position_bias.masked_fill(position_bias == 1, torch.finfo(scores.dtype).min)
#     220 scores += position_bias_masked
# --> 221 scores = torch.max(scores, torch.tensor(torch.finfo(scores.dtype).min))
#     223 # (batch_size, n_heads, seq_length, key_length)
#     224 attn_weights = nn.functional.softmax(scores, dim=-1, dtype=torch.float32).type_as(scores)
#
# KeyboardInterrupt:

# %%
model.push_to_hub("modelD")

# %%
plt.ylim(-0.01,1.1)
plt.yticks(np.linspace(0,1,21))
plt.tick_params(axis='y', labelsize = 8)
plt.grid(axis = 'y', linewidth = 0.5)
plt.xlabel("epochs")
plt.ylabel("accuracies")

plt.plot(np.arange(0, len(accuracies_train) * eval_step, eval_step), accuracies_train, label = "accuracy train")
plt.plot(losses, label = "loss")
plt.plot(np.arange(0, len(accuracies_test) * eval_step, eval_step), accuracies_test, label = "accuracy test")

plt.axhline(y = 1, xmin = 0, xmax = 800, color = "gray", linestyle = "dashed", alpha = 0.4)

plt.legend()

# %%
accuracies_train

# %%
results = []

for data in ploty_dataset_test:

    image = data["image"]

    model.eval()
    inputs = processor(images=image, return_tensors="pt", max_patches=512).to(device)

    flattened_patches = inputs.flattened_patches
    attention_mask = inputs.attention_mask

    generated_ids = model.generate(flattened_patches=flattened_patches, attention_mask=attention_mask, max_length=50)
    generated_caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

    results.append([data["text"], generated_caption])

accuracy = np.mean([res[0] == res[1] for res in results])

print("Accuracy: " + str(accuracy))
results

# %%
import time

start_time = time.time()

for i in range(100000):
    a = 1

end_time = time.time()
elapsed_time = end_time - start_time
